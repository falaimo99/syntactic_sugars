# %% [markdown]
# Please use this Jupyter notebook to check the correctness of th queries.

# %%
class Processor:
    def __init__(self):
        self.dbPathorUrl = str()

    def getdbPathorUrl(self):
        return self.dbPathorUrl
    
    def setdbPathorUrl(self, PathorUrl):
        self.dbPathorUrl = PathorUrl

class RelationalQueryProcessor(Processor):
    def __init__(self, dbPathOrUrl):
        super().__init__(dbPathOrUrl)

    def uploadData(self, path):
        pass

# %%
from sqlite3 import connect
from pandas import read_csv, Series, DataFrame, read_sql
import pandas as pd
pd.options.mode.chained_assignment = None


def getAllAnnotations():
    with connect("relational.db") as con: 
        query_1 = "SELECT annotation,target,body,motivation FROM Annotation LEFT JOIN image ON Annotation.imageId == image.imageId"
        all_annotations_query = read_sql(query_1,con)
    return all_annotations_query
getAllAnnotations()
# Out:
#                                             annotation
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  \
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 267  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 268  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 269  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 270  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
#
#                                                 target
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1  \
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p2
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p3
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p4
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p5
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...
# 267  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...
# 268  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...
# 269  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...
# 270  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...
#
#                                                   body motivation
# 0    https://dl.ficlit.unibo.it/iiif/2/45498/full/6...   painting
# 1    https://dl.ficlit.unibo.it/iiif/2/45499/full/6...   painting
# 2    https://dl.ficlit.unibo.it/iiif/2/45500/full/6...   painting
# 3    https://dl.ficlit.unibo.it/iiif/2/45501/full/6...   painting
# 4    https://dl.ficlit.unibo.it/iiif/2/45502/full/6...   painting
# ..                                                 ...        ...
# 266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...   painting
# 267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...   painting
# 268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...   painting
# 269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...   painting
# 270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...   painting
#
# [271 rows x 4 columns]

# %%
def getAllImages():
    with connect("relational.db") as con: 
        query_2 = "SELECT body FROM image"
        all_images_query = read_sql(query_2,con)
    return all_images_query
getAllImages()
# Out:
#                                                   body
# 0    https://dl.ficlit.unibo.it/iiif/2/45498/full/6...
# 1    https://dl.ficlit.unibo.it/iiif/2/45499/full/6...
# 2    https://dl.ficlit.unibo.it/iiif/2/45500/full/6...
# 3    https://dl.ficlit.unibo.it/iiif/2/45501/full/6...
# 4    https://dl.ficlit.unibo.it/iiif/2/45502/full/6...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...
# 267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...
# 268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...
# 269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...
# 270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...
#
# [271 rows x 1 columns]

# %%
def getAnnotationsWithBody(): #Here I'm using the first annotation as an example just to test the query. Gonna replace it with a general one later.
    with connect("relational.db") as con: 
        query_3 = "SELECT annotation,target,body,motivation FROM Annotation LEFT JOIN image ON Annotation.imageId == image.imageId WHERE body='https://dl.ficlit.unibo.it/iiif/2/45498/full/699,800/0/default.jpg'"
        annotations_with_body_query = read_sql(query_3,con)
    return annotations_with_body_query
getAnnotationsWithBody()
# Out:
#                                           annotation
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/annota...  \
#
#                                               target
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1  \
#
#                                                 body motivation
# 0  https://dl.ficlit.unibo.it/iiif/2/45498/full/6...   painting

# %%
def getAnnotationsWithBodyAndTarget(): #Here I'm using the first annotation as an example just to test the query. Gonna replace it with a general one later.
    with connect("relational.db") as con:
        query_4 = "SELECT annotation,target,body,motivation FROM Annotation LEFT JOIN image ON Annotation.imageId == image.imageId WHERE body='https://dl.ficlit.unibo.it/iiif/2/45498/full/699,800/0/default.jpg' AND target='https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1'"
        annotations_with_body_and_target_query = read_sql(query_4,con)
    return annotations_with_body_and_target_query
getAnnotationsWithBodyAndTarget()
# Out:
#                                           annotation
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/annota...  \
#
#                                               target
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1  \
#
#                                                 body motivation
# 0  https://dl.ficlit.unibo.it/iiif/2/45498/full/6...   painting

# %%
def getAnnotationsWithTarget(): 
    with connect("relational.db") as con:
        query_5 = "SELECT annotation,target,body,motivation FROM Annotation LEFT JOIN image ON Annotation.imageId == image.imageId WHERE target='https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1'"
        annotations_with_target_query = read_sql(query_5,con)
    return annotations_with_target_query
getAnnotationsWithTarget()
# Out:
#                                           annotation
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/annota...  \
#
#                                               target
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1  \
#
#                                                 body motivation
# 0  https://dl.ficlit.unibo.it/iiif/2/45498/full/6...   painting

# %%
def getEntitiesWithCreator(): 
    with connect("relational.db") as con:
        query_6 = "SELECT DISTINCT id,title,creators FROM EntityWithMetadata LEFT JOIN creators_table ON EntityWithMetadata.creatorId == creators_table.creatorId WHERE creator= 'Doe, John'"
        entities_with_creator_query = read_sql(query_6,con)
    return entities_with_creator_query
getEntitiesWithCreator()
# Out:
#                                                  id                   title
# 0  https://dl.ficlit.unibo.it/iiif/28429/collection  Dante Alighieri: Opere  \
#
#                creators
# 0  Doe, John; Doe, Jane

# %%
def getEntitiesWithTitle(): #Here I'm using Canzoniere as an example just to test the query. Gonna replace it with a general one later.
    with connect("relational.db") as con:
        query_7 = "SELECT id,title,creators FROM EntityWithMetadata LEFT JOIN creators_table ON EntityWithMetadata.creatorId == creators_table.creatorId WHERE title= 'Il Canzoniere'"
        entities_with_title_query = read_sql(query_7,con)
    return entities_with_title_query
getEntitiesWithTitle()
# Out:
#                                                  id          title
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/manifest  Il Canzoniere  \
#
#            creators
# 0  Alighieri, Dante
