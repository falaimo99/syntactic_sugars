# %% [markdown]
# ### First UML Classes

# %%
class IdentifiableEntity(object):
    def __init__(self, id):
        self.id = id
    def getId(self):
        return self.id

class Annotation(IdentifiableEntity): 
    def __init__(self, id, motivation, body, target):
        self.motivation = motivation
        self.body = body
        self.target = target
        super().__init__(id)
    def getBody(self):
        return Image
    def getMotivation(self):
        return self.motivation
    def getTarget(self):
        return IdentifiableEntity

class Image(IdentifiableEntity):
    pass

# %%
# class EntityWithMetadata(IdentifiableEntity):
#     def __init__(self, id, label, title, creators):
#         self.label = label 
#         self.title = title
#         super().__init__(id)
#         self.id = list()
#         for creator in creators:
#             self.id.append(creator)
            

#     def getLabel(self):
#         return self.label
#     def getTitle(self):
#         if len(self.title) == 0:
#             return None
#         if len(self.title) == 1:
#             return self.title
#     def getCreators(self):
#         return self.id

# %% [markdown]
# ### Processor classes

# %%
class Processor(object): #it needs to be modified
    def __init__(self, dbPathOrUrl):
        self.dbPathOrUrl = dbPathOrUrl
        self.dbPathOrUrl = ""
        
    def setDbPathOrUrl(self, new_path):
        self.dbPathOrUrl= new_path
    def getDbPathOrUrl(self):
        return self.dbPathOrUrl
    
class AnnotationProcessor(Processor):
    def __init__(self, dbPathOrUrl):
        super().__init__(dbPathOrUrl)

    def uploadData(self, annotations_path): 
        pass
        #annotations_path is the path of the csv annotation file
        # this method allows to upload the csv contents into the database.

# %% [markdown]
# ### Database Creation

# %%
from sqlite3 import connect
with connect("relational.db") as con:
    con.commit()

# %% [markdown]
# ### Tables Creation
# First, we need to convert the UML classes into dataframes, starting from the classes that do not have any subclasses. Then, we will use these tables to upload the data into the database.

# %%
from pandas import read_csv, Series

annotations = read_csv("data/annotations.csv", keep_default_na=False, dtype={"id":"string", "body":"string", "target":"string", "motivation":"string"})

annotations_ids = annotations[["id", "body", "target", "motivation"]]
annotations_internal_id = []
for idx, row in annotations_ids.iterrows():
    annotations_internal_id.append("annotations-" + str(idx))

annotations_ids.insert(0, "annotationsId", Series(annotations_internal_id, dtype="string"))
annotations_ids
# Out:
#        annotationsId                                                 id  \
# 0      annotations-0  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 1      annotations-1  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 2      annotations-2  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 3      annotations-3  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 4      annotations-4  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# ..               ...                                                ...
# 266  annotations-266  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 267  annotations-267  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 268  annotations-268  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 269  annotations-269  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 270  annotations-270  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
#
#                                                   body  \
# 0    https://dl.ficlit.unibo.it/iiif/2/45498/full/6...
# 1    https://dl.ficlit.unibo.it/iiif/2/45499/full/6...
# 2    https://dl.ficlit.unibo.it/iiif/2/45500/full/6...
# 3    https://dl.ficlit.unibo.it/iiif/2/45501/full/6...
# 4    https://dl.ficlit.unibo.it/iiif/2/45502/full/6...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...
# 267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...
# 268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...
# 269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...
# 270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...
#
#                                                 target motivation
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1   painting
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p2   painting
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p3   painting
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p4   painting
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p5   painting
# ..                                                 ...        ...
# 266  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting
# 267  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting
# 268  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting
# 269  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting
# 270  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting
#
# [271 rows x 5 columns]

# %%
image_ids = annotations[["body"]]
image_ids = image_ids.rename(columns={"body": "id"})
image_internal_id = []
for idx, row in annotations_ids.iterrows():
    image_internal_id.append("image-" + str(idx))

image_ids.insert(0, "imageId", Series(image_internal_id, dtype="string"))
image_ids
# Out:
#        imageId                                                 id
# 0      image-0  https://dl.ficlit.unibo.it/iiif/2/45498/full/6...
# 1      image-1  https://dl.ficlit.unibo.it/iiif/2/45499/full/6...
# 2      image-2  https://dl.ficlit.unibo.it/iiif/2/45500/full/6...
# 3      image-3  https://dl.ficlit.unibo.it/iiif/2/45501/full/6...
# 4      image-4  https://dl.ficlit.unibo.it/iiif/2/45502/full/6...
# ..         ...                                                ...
# 266  image-266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...
# 267  image-267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...
# 268  image-268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...
# 269  image-269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...
# 270  image-270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...
#
# [271 rows x 2 columns]

# %%
from pandas import merge 

df_joined= merge(annotations_ids, image_ids, left_on="body", right_on="id")
df_joined = df_joined.rename(columns={"id_y": "body"})
df_joined
# Out:
#        annotationsId                                               id_x  \
# 0      annotations-0  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 1      annotations-1  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 2      annotations-2  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 3      annotations-3  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# 4      annotations-4  https://dl.ficlit.unibo.it/iiif/2/28429/annota...
# ..               ...                                                ...
# 266  annotations-266  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 267  annotations-267  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 268  annotations-268  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 269  annotations-269  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
# 270  annotations-270  https://dl.ficlit.unibo.it/iiif/2/19425/annota...
#
#                                                   body  \
# 0    https://dl.ficlit.unibo.it/iiif/2/45498/full/6...
# 1    https://dl.ficlit.unibo.it/iiif/2/45499/full/6...
# 2    https://dl.ficlit.unibo.it/iiif/2/45500/full/6...
# 3    https://dl.ficlit.unibo.it/iiif/2/45501/full/6...
# 4    https://dl.ficlit.unibo.it/iiif/2/45502/full/6...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...
# 267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...
# 268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...
# 269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...
# 270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...
#
#                                                 target motivation    imageId  \
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p1   painting    image-0
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p2   painting    image-1
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p3   painting    image-2
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p4   painting    image-3
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/canvas/p5   painting    image-4
# ..                                                 ...        ...        ...
# 266  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting  image-266
# 267  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting  image-267
# 268  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting  image-268
# 269  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting  image-269
# 270  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   painting  image-270
#
#                                                   body
# 0    https://dl.ficlit.unibo.it/iiif/2/45498/full/6...
# 1    https://dl.ficlit.unibo.it/iiif/2/45499/full/6...
# 2    https://dl.ficlit.unibo.it/iiif/2/45500/full/6...
# 3    https://dl.ficlit.unibo.it/iiif/2/45501/full/6...
# 4    https://dl.ficlit.unibo.it/iiif/2/45502/full/6...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/206738/full/...
# 267  https://dl.ficlit.unibo.it/iiif/2/206739/full/...
# 268  https://dl.ficlit.unibo.it/iiif/2/206740/full/...
# 269  https://dl.ficlit.unibo.it/iiif/2/206741/full/...
# 270  https://dl.ficlit.unibo.it/iiif/2/206742/full/...
#
# [271 rows x 7 columns]

# %%
with connect("relational.db") as con:
    df_joined.to_sql("annotationsId", con, if_exists="replace", index=False)
