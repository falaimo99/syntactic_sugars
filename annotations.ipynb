# %%
class IdentifiableEntity(object):
    def __init__(self, id):
        self.id = id
    def getId(self):
        return self.id

class Annotation(IdentifiableEntity): 
    def __init__(self, id, motivation, body, target):
        self.motivation = motivation
        self.body = body
        self.target = target
        super().__init__(id)
    def getBody(self):
        return Image
    def getMotivation(self):
        return self.motivation
    def getTarget(self):
        return IdentifiableEntity

class Image(IdentifiableEntity):
    pass

# %%
# class EntityWithMetadata(IdentifiableEntity):
#     def __init__(self, id, label, title, creators):
#         self.label = label 
#         self.title = title
#         super().__init__(id)
#         self.id = list()
#         for creator in creators:
#             self.id.append(creator)
            

#     def getLabel(self):
#         return self.label
#     def getTitle(self):
#         if len(self.title) == 0:
#             return None
#         if len(self.title) == 1:
#             return self.title
#     def getCreators(self):
#         return self.id

# %%
class Processor(object): #it needs to be modified
    def __init__(self, dbPathOrUrl):
        self.dbPathOrUrl = dbPathOrUrl
        dbPathOrUrl = ""
    def setDbPathOrUrl(self, dbPathOrUrl, new_path):
        dbPathOrUrl= new_path
        new_path = dbPathOrUrl
    def getDbPathOrUrl(self, dbPathOrUrl):
        return dbPathOrUrl
    
class AnnotationProcessor(Processor):
    def uploadData(self, annotations_path): #annotations_path is the path of the csv annotation file
        pass

# %%
from pandas import read_csv

annotations = read_csv("data/annotations.csv", keep_default_na=False, dtype = {"id": "string", "body": "string", "target": "string", "motivation":"string"})
annotations
# Out:
#                                                     id  ... motivation
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  ...   painting
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  ...   painting
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  ...   painting
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  ...   painting
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/annota...  ...   painting
# ..                                                 ...  ...        ...
# 266  https://dl.ficlit.unibo.it/iiif/2/19425/annota...  ...   painting
# 267  https://dl.ficlit.unibo.it/iiif/2/19425/annota...  ...   painting
# 268  https://dl.ficlit.unibo.it/iiif/2/19425/annota...  ...   painting
# 269  https://dl.ficlit.unibo.it/iiif/2/19425/annota...  ...   painting
# 270  https://dl.ficlit.unibo.it/iiif/2/19425/annota...  ...   painting
#
# [271 rows x 4 columns]
